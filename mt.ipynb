# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
ax = plt.subplot()
# plt.show()
plt.plot([1,2,3,4],[1,4,2,3])
# plt.show()
fig = plt.figure()
# plt.show
axs = plt.subplots(2,2)
plt.show()

# %%
axs =plt.subplots(2,2)
plt.show()

# %%
Dict = {1:'Greeks',2:"For",3:'Greek'}
print(Dict)
list1 =[1,2,3,4,5]
print(list1)
tuple1 =(1,2,3,4)
print(tuple1)

# %%
import numpy as np
x = np.linspace(0,2,100)
ax = plt.subplots()
# plt.plot(x,x,'linear')
# plt.plot(x,x**2,'quadriatic')
# plt.plot(x,x**3,'cubic')
# plt.xlabel('x lable')
# plt.ylabel('y lable')
plt.title('Simple Plot')
plt.title('Simple Plot')
plt.legend()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2932\2505123851.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
x = torch.rand(5, 3)
a = pd.Series([1,2,3])
print(x)
print(a)
x = np.linspace(2,100)
y = np.linspace(0,2,100)
ax = plt.subplot()
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='Quadric')
plt.plot(x,x**3,label='Cubic')
plt.title(label='Simple Plot')
plt.plot(y,y,label='Linear')

plt.legend()
# Out:
# tensor([[0.4311, 0.4571, 0.1142],
#         [0.4920, 0.9160, 0.0991],
#         [0.4909, 0.6555, 0.7186],
#         [0.2570, 0.1328, 0.0192],
#         [0.5730, 0.7865, 0.0181]])
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7582, 0.1774, 0.0209],
#         [0.7932, 0.9857, 0.5016],
#         [0.8600, 0.3822, 0.0247],
#         [0.3815, 0.0464, 0.5346],
#         [0.3531, 0.2137, 0.2835]])
